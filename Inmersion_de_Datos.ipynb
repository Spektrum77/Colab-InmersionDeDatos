# %% [markdown]
# <a href="https://colab.research.google.com/github/Spektrum77/Colab-InmersionDeDatos/blob/main/Inmersion_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np



inmuebles = pd.read_csv('/content/drive/MyDrive/inmuebles_bogota.csv')

# %%
inmuebles
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Baños  Área                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %% [markdown]
# # 1. Promedio de área de todos los inmuebles en los barrios en el dataset. El top 10.

# %%
inmuebles.groupby('Barrio')['Área'].mean().sort_values(ascending=False)
# Out:
# Barrio
# Modelia            4316.750000
# Libertador          642.000000
# Bosa Piamonte       400.000000
# La Soledad          378.625000
# Restrepo            336.500000
#                       ...
# La Merced            41.000000
# El Tunal             41.000000
# San Diego            40.666667
# La Macarena          37.000000
# Prado Veraniego      25.000000
# Name: Área, Length: 149, dtype: float64

# %%
inmuebles.groupby('Barrio')['Área'].mean().sort_values(ascending=False).head().plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %%
inmuebles.groupby('Barrio')['Área'].describe().sort_values(by='max', ascending = False)
# Out:
#                      count         mean           std   min    25%    50%  \
# Barrio
# Modelia               40.0  4316.750000  26259.427757  48.0  87.75  155.5
# Chapinero            332.0   244.722892   1229.732676  15.0  70.00  110.0
# Barrios Unidos       473.0   185.621564    653.452408  28.0  62.00   87.0
# Usaquén             1105.0   134.046154    215.719357  24.0  70.00   93.0
# Zona Noroccidental   877.0   135.785633    223.813808  16.0  61.00   78.0
# ...                    ...          ...           ...   ...    ...    ...
# Las Cruces             2.0    45.000000      0.000000  45.0  45.00   45.0
# Bosa Porvenir          2.0    42.000000      0.000000  42.0  42.00   42.0
# El Tunal               1.0    41.000000           NaN  41.0  41.00   41.0
# La Macarena            1.0    37.000000           NaN  37.0  37.00   37.0
# Prado Veraniego        1.0    25.000000           NaN  25.0  25.00   25.0
#
#                       75%       max
# Barrio
# ...

# %% [markdown]
# # 2. Consultar otros datos estadísticos, conteo, mediana, valores mínimo y máximo.

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Baños           Área
# count   9520.000000  9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706
# std        2.049856     1.255314    1731.379622
# min        1.000000     0.000000       2.000000
# 25%        2.000000     2.000000      57.000000
# 50%        3.000000     2.000000      80.000000
# 75%        3.000000     3.000000     135.000000
# max      110.000000     9.000000  166243.000000
